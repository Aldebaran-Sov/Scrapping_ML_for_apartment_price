# %%
import pandas as pd
import csv

# %% [markdown]
# # V. Clean data

# %%
df = pd.read_csv("extract_cost_of_living.csv")
# print(df)

# %%
# ~ devant une condition pour l'inverse
df[~df['Price'].str.contains(r'\$')]
# Out:
#               Country                                               Item  \
# 54        Afghanistan  Mortgage Interest Rate in Percentages (%), Yea...
# 109     Aland Islands  Mortgage Interest Rate in Percentages (%), Yea...
# 164           Albania  Mortgage Interest Rate in Percentages (%), Yea...
# 175          Alderney                               Rice (white), (1kg)
# 176          Alderney                               Eggs (regular) (12)
# ...               ...                                                ...
# 12686  Western Sahara  Mobile Phone Monthly Plan with Calls and 10GB+...
# 12704  Western Sahara  Mortgage Interest Rate in Percentages (%), Yea...
# 12759           Yemen  Mortgage Interest Rate in Percentages (%), Yea...
# 12814          Zambia  Mortgage Interest Rate in Percentages (%), Yea...
# 12869        Zimbabwe  Mortgage Interest Rate in Percentages (%), Yea...
#
#         Price
# 54      17.31
# 109      3.90
# 164      5.63
# 175         ?
# 176         ?
# ...       ...
# 12686       ?
# 12704       ?
# 12759   12.67
# 12814   21.25
# 12869   14.21
#
# [812 rows x 3 columns]

# %%
# store others values that are not prices
otherThenPrice = df[~(df['Price'].str.contains(r'\$')) & ~(df['Price'].str.contains(r'\?'))]
otherThenPrice.to_csv("otherThenPrice_cost_of_living.csv", index=False, quoting=csv.QUOTE_NONNUMERIC)

# %%
df = df[df['Price'].str.contains(r'\$')]

# %%
df
# Out:
#            Country                                               Item  \
# 0      Afghanistan                      Meal, Inexpensive Restaurant
# 1      Afghanistan  Meal for 2 People, Mid-range Restaurant, Three...
# 2      Afghanistan    McMeal at McDonalds (or Equivalent Combo Meal)
# 3      Afghanistan   Domestic Non-Alcoholic Beer (0.5 liter draught)
# 4      Afghanistan   Imported Non-Alcoholic Beer (0.33 liter bottle)
# ...            ...                                                ...
# 12864     Zimbabwe             Apartment (3 bedrooms) in City Centre
# 12865     Zimbabwe          Apartment (3 bedrooms) Outside of Centre
# 12866     Zimbabwe  Price per Square Meter to Buy Apartment in Cit...
# 12867     Zimbabwe  Price per Square Meter to Buy Apartment Outsid...
# 12868     Zimbabwe            Average Monthly Net Salary (After Tax)
#
#              Price
# 0           2.05 $
# 1          10.13 $
# 2           3.42 $
# 3           2.74 $
# 4           6.84 $
# ...            ...
# 12864     722.73 $
# 12865     511.74 $
# 12866   1,050.00 $
# 12867   1,424.13 $
# 12868     367.91 $
#
# [12058 rows x 3 columns]

# %%
df["Price"] = df["Price"].str.replace(",", "")
df["Price"] = df["Price"].str.extract(r'(\d+\.?\d*)')

# %%
df
# Out:
#            Country                                               Item    Price
# 0      Afghanistan                      Meal, Inexpensive Restaurant      2.05
# 1      Afghanistan  Meal for 2 People, Mid-range Restaurant, Three...    10.13
# 2      Afghanistan    McMeal at McDonalds (or Equivalent Combo Meal)      3.42
# 3      Afghanistan   Domestic Non-Alcoholic Beer (0.5 liter draught)      2.74
# 4      Afghanistan   Imported Non-Alcoholic Beer (0.33 liter bottle)      6.84
# ...            ...                                                ...      ...
# 12864     Zimbabwe             Apartment (3 bedrooms) in City Centre    722.73
# 12865     Zimbabwe          Apartment (3 bedrooms) Outside of Centre    511.74
# 12866     Zimbabwe  Price per Square Meter to Buy Apartment in Cit...  1050.00
# 12867     Zimbabwe  Price per Square Meter to Buy Apartment Outsid...  1424.13
# 12868     Zimbabwe            Average Monthly Net Salary (After Tax)    367.91
#
# [12058 rows x 3 columns]

# %% [markdown]
# # VI Save clean data

# %%
# data to csv
df.to_csv("clean_cost_of_living.csv", index=False, quoting=csv.QUOTE_NONNUMERIC)

# %%
a = pd.read_csv("clean_cost_of_living.csv")

# %%
a.dtypes
# Out:
# Country     object
# Item        object
# Price      float64
# dtype: object
